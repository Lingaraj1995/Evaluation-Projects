# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['W']
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(10,2,plotnumber)
        sns.distplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(10,2,plotnumber)
        sns.histplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(10,2,plotnumber)
        sns.boxplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(7,4,plotnumber)
        plt.scatter(df[column],df['W'], color='b')
        plt.xlabel(column,fontsize=26)
        plt.ylabel('W', fontsize=26)
    plotnumber += 1
plt.tight_layout()

# %%
sns.pairplot(df)

# %%
corr=df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr,cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df_new.shape
# Out:
# (29, 17)

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
from scipy.stats import boxcox

# %%
df_new['CG']=boxcox(df_new['CG'],0.5)

# %%
df_new['CG'].skew()
# Out:
# -0.26067780758121417

# %%
df_new['SHO']=boxcox(df_new['SHO'],0.5)

# %%
df_new['SHO'].skewew()
# Out:
# -0.08580249517743858

# %%
df_new['SV']=boxcox(df_new['SV'],0.5)

# %%
df_new['SV'].skew()
# Out:
# 0.370279952542934

# %%
df_new['E']=boxcox(df_new['E'],0.5)

# %%
df_new['E'].skew()
# Out:
# 0.7149657245319962

# %%
df_new['H']=boxcox(df_new['H'],0.5)

# %%
df_new['H'].skew()
# Out:
# 0.7612737602321513

# %%
y=df_new.iloc[:,0]

# %%
x=df_new.iloc[:,1:]

# %%
x
# Out:
#       R    AB          H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   724  5575  75.382168  300  42  139  383   973  104  641  601  3.73
# 1   696  5467  71.457471  277  44  156  439  1264   70  700  653  4.07
# 2   669  5439  72.699398  303  29  141  533  1157   86  640  584  3.67
# 3   622  5533  72.323617  260  27  136  404  1231   68  701  643  3.98
# 4   689  5605  75.846002  289  49  151  455  1259   83  803  746  4.64
# 6   764  5567  72.752926  272  19  212  554  1227   63  698  652  4.03
# 7   713  5485  72.027022  246  20  217  418  1331   44  693  646  4.05
# 8   644  5485  72.377416  278  32  167  436  1310   87  642  604  3.74
# 9   748  5640  75.330460  294  33  161  478  1148   71  753  694  4.31
# 10  751  5511  73.339233  279  32  172  503  1233  101  733  680  4.24
# 11  729  5459  71.837660  278  26  230  486  1392  121  618  572  3.57
# 12  661  5417  70.965745  243  21  176  435  1150   52  675  630  3.94
# 13  656  5544  72.269779  262  22  198  478  1336   69  726  677  4.16
# 14  694  5600  72.966659  277  46  146  475  1119   78  729  664  4.14
# 15  647  5484  72.458042  288  39  137  506  1267   69  525  478  2.94
# 16  697  5631  74.472217  292  27  140  461  1322   98  596  532  3.21
# 17  689  5491  71.239334  272  30  171  567  1518   95  608  546  3.36
# 18  655  5480  72.242845  274  34  145  412  1299   84  737  682  4.28
# 19  640  5571  72.350521  257  27  167  496  1255  134  754  700  4.33
# 20  683  5527  71.511904  295  17  177  488  1290   51  613  557  3.43
# 21  703  5428  71.837660  265  13  177  539  1344   57  635  577  3.62
# 22  613  5463  73.365775  236  40  120  375  1150  112  678  638  4.02
# 23  573  5420  71.783467  251  18  100  471  1107   69  760  698  4.41
# 24  626  5529  72.135012  272  37  130  387  1274   88  809  749  4.69
# 25  667  5385  71.375745  263  26  187  563  1258   59  595  553  3.44
# 26  696  5565  75.097341  288  39  136  457  1159   93  627  597  3.72
# 27  720  5649  75.304592  289  48  154  490  1312  132  713  659  4.04
# 28  650  5457  70.773622  260  36  148  426  1327   82  731  655  4.09
# 29  737  5572  74.915538  274  49  186  388  1283   97  844  799  5.04
#
#           CG       SHO         SV          E
# 0   0.828427  3.656854  12.966630  16.761663
# 1   0.828427  4.928203  11.416408  16.547237
# 2   4.633250  4.324555  10.328828  15.776389
# 3   3.291503  4.000000  10.165525  18.099751
# 4   3.291503  4.928203   9.832160  16.547237
# 6   1.464102  2.000000  11.856406  17.287302
# 7  -2.000000  4.324555  11.114877  15.549929
# 8   0.000000  4.928203  13.491933  17.493589
# 9   1.464102  4.324555  10.649111  17.697716
# 10  2.472136  4.000000  11.416408  19.817424
# 11  2.472136  5.211103  10.489996  16.439089
# 12  0.828427  4.928203  11.564660  17.287302
# 13  2.898979  4.928203  11.416408  17.390719
# 14  2.472136  5.745967   8.583005  20.449944
# 15  0.000000  5.745967  13.748016  17.595918
# 16 -2.000000  5.211103  12.696938  20.090722
# 17  2.898979  7.165151  11.856406  19.071308
# 18  0.000000  3.291503  10.649111  19.540659
# 19  0.828427  3.656854   9.832160  16.973666
# 20  0.000000  5.483315  12.142136  16.761663
# 21  2.000000  5.211103  10.806248  16.973666
# 22 -2.000000  4.928203   9.832160  15.549929
# 23  1.464102  4.324555  11.266499  16.973666
# 24  0.000000  3.291503   9.832160  19.633308
# 25  2.898979  7.165151  11.711309  15.320508
# 26  3.291503  6.485281  10.806248  15.663522
# 27  0.000000  4.928203  11.266499  16.547237
# 28  0.000000  2.898979  10.806248  17.183326
# 29  2.000000  2.000000  10.000000  17.493589

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
sc=StandardScaler()

# %%
X = pd.DataFrame(sc.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.731088  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.944305  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.097707  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.353870 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.047274  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.253549 -0.777436
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.253549  0.247475
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.020463 -0.239162
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.218547 -0.500806
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.218547  0.247475
#
#          SV         E
# 0  1.602631 -0.454325
# 1  0.255621 -0.607619
# 2 -0.689393 -1.158698
# 3 -0.831290  0.502274
# 4 -1.120956 -0.607619

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.116703        R
# 1      17.861133       AB
# 2       9.390295        H
# 3       3.732577       2B
# 4       3.139536       3B
# 5       8.526546       HR
# 6       3.383955       BB
# 7       2.747217       SO
# 8       1.959083       SB
# 9     194.613528       RA
# 10   1894.633729       ER
# 11   1480.131488      ERA
# 12      2.852086       CG
# 13      3.274784      SHO
# 14      5.319701       SV
# 15      2.138126        E

# %%
X=X.drop(['ERA'],axis=1)

# %%
X=X.drop(['ER'],axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.354433        R
# 1       4.790539       AB
# 2       7.255706        H
# 3       3.338170       2B
# 4       2.970761       3B
# 5       6.260414       HR
# 6       3.102173       BB
# 7       2.255128       SO
# 8       1.782497       SB
# 9       4.966482       RA
# 10      2.506589       CG
# 11      3.096856      SHO
# 12      2.558365       SV
# 13      2.050083        E

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()

for i in range(0,100):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=i)
    lr.fit(X_train,y_train)
    lr_pred_train=lr.predict(X_train)
    lr_pred_test=lr.predict(X_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,lr_pred_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,lr_pred_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9665117885796506
# At random state0, The test accuracy is :-0.29576579835383265
#
#
# At random state1, The training accuracy is :-0.9490277890315029
# At random state1, The test accuracy is :-0.6816689870044164
#
#
# At random state2, The training accuracy is :-0.9429508078428441
# At random state2, The test accuracy is :--0.5965756725709048
#
#
# At random state3, The training accuracy is :-0.9254667951163746
# At random state3, The test accuracy is :-0.8191035119491191
#
#
# At random state4, The training accuracy is :-0.9415527353334175
# At random state4, The test accuracy is :-0.7516086683277019
#
#
# At random state5, The training accuracy is :-0.9427466603915742
# At random state5, The test accuracy is :-0.4099108545609357
#
#
# At random state6, The training accuracy is :-0.9084715275477431
# At random state6, The test accuracy is :-0.9082521666901878
#
#
# At random state7, The training accuracy is :-0.9363158611158934
# At random state7, The test accuracy is :-0.7033515120647083
#
#
# At random state8, The training accuracy is :-0.9663042224059407
# At random state8, The test accuracy is :-0.6841413343107218
#
#
# At random state9, The training accuracy is :-0.9780344609700484
# At random state9, The test accuracy is :-0.35801170815394556
#
#
# At random state10, The training accuracy is :-0.9635100132258029
# At random state10, The test accuracy is :-0.23540898890385153
#
#
# At random state11, The training accuracy is :-0.9492822544009261
# At random state11, The test accuracy is :-0.04605007353349033
#
#
# At random state12, The training accuracy is :-0.9690691870032205
# At random state12, The test accuracy is :-0.19466640218983733
#
#
# At random state13, The training accuracy is :-0.9490112731868076
# At random state13, The test accuracy is :-0.4871088891722051
#
#
# At random state14, The training accuracy is :-0.9335406046766005
# At random state14, The test accuracy is :-0.7806072863940872
#
#
# At random state15, The training accuracy is :-0.9010966892106594
# At random state15, The test accuracy is :-0.9456095835827363
#
#
# At random state16, The training accuracy is :-0.9591183357481206
# At random state16, The test accuracy is :-0.3414446732130395
#
#
# At random state17, The training accuracy is :-0.9304885454957509
# At random state17, The test accuracy is :-0.6975827794255754
#
#
# At random state18, The training accuracy is :-0.9616284014356765
# At random state18, The test accuracy is :-0.0868169056974194
#
#
# At random state19, The training accuracy is :-0.9530585867753972
# At random state19, The test accuracy is :--0.655336769262933
#
#
# At random state20, The training accuracy is :-0.9693241056556813
# At random state20, The test accuracy is :--1.5882645333949599
#
#
# At random state21, The training accuracy is :-0.9573542946809483
# At random state21, The test accuracy is :-0.4584548640865864
#
#
# At random state22, The training accuracy is :-0.9366196041663944
# At random state22, The test accuracy is :-0.5643394220655404
#
#
# At random state23, The training accuracy is :-0.9785428236357172
# At random state23, The test accuracy is :--0.22233601632671074
#
#
# At random state24, The training accuracy is :-0.9353616041419545
# At random state24, The test accuracy is :--0.060832843809243364
#
#
# At random state25, The training accuracy is :-0.9378258432876564
# At random state25, The test accuracy is :-0.4349988970326397
#
#
# At random state26, The training accuracy is :-0.9493517789878362
# At random state26, The test accuracy is :--0.14968453869907172
#
#
# At random state27, The training accuracy is :-0.9676766443554357
# At random state27, The test accuracy is :-0.6150181801994682
#
#
# At random state28, The training accuracy is :-0.9590828599855055
# At random state28, The test accuracy is :-0.3836806147726213
#
#
# At random state29, The training accuracy is :-0.9284090550599071
# At random state29, The test accuracy is :-0.8294120602555582
#
#
# At random state30, The training accuracy is :-0.9414186250402716
# At random state30, The test accuracy is :-0.767456505876184
#
#
# At random state31, The training accuracy is :-0.966216568464084
# At random state31, The test accuracy is :--0.0030864576251683484
#
#
# At random state32, The training accuracy is :-0.9673728916475575
# At random state32, The test accuracy is :-0.07838088957401468
#
#
# At random state33, The training accuracy is :-0.9517237230274036
# At random state33, The test accuracy is :-0.42935117255380006
#
#
# At random state34, The training accuracy is :-0.9783872630243419
# At random state34, The test accuracy is :-0.15510437422789014
#
#
# At random state35, The training accuracy is :-0.964252275798499
# At random state35, The test accuracy is :-0.7206959817077222
#
#
# At random state36, The training accuracy is :-0.9369297112632275
# At random state36, The test accuracy is :--0.013158337248624141
#
#
# At random state37, The training accuracy is :-0.9579260969484112
# At random state37, The test accuracy is :-0.25338740398647397
#
#
# At random state38, The training accuracy is :-0.9447447434883023
# At random state38, The test accuracy is :-0.3288738266561507
#
#
# At random state39, The training accuracy is :-0.9717262491440172
# At random state39, The test accuracy is :--0.08417127075835595
#
#
# At random state40, The training accuracy is :-0.9533787278491672
# At random state40, The test accuracy is :-0.2665616730263586
#
#
# At random state41, The training accuracy is :-0.9435593119105621
# At random state41, The test accuracy is :-0.6369192257207574
#
#
# At random state42, The training accuracy is :-0.927607620899463
# At random state42, The test accuracy is :-0.7628725166735915
#
#
# At random state43, The training accuracy is :-0.9640735595867568
# At random state43, The test accuracy is :-0.21725665174254283
#
#
# At random state44, The training accuracy is :-0.9358250551501897
# At random state44, The test accuracy is :-0.6631171204711381
#
#
# At random state45, The training accuracy is :-0.960518050218055
# At random state45, The test accuracy is :-0.4890987412391139
#
#
# At random state46, The training accuracy is :-0.9242435434648435
# At random state46, The test accuracy is :-0.9079977901793759
#
#
# At random state47, The training accuracy is :-0.9079818974544489
# At random state47, The test accuracy is :-0.9573746744931759
#
#
# At random state48, The training accuracy is :-0.9764667979424038
# At random state48, The test accuracy is :--0.27642359994969357
#
#
# At random state49, The training accuracy is :-0.9479342692319672
# At random state49, The test accuracy is :--0.4268685829766259
#
#
# At random state50, The training accuracy is :-0.9176110316259976
# At random state50, The test accuracy is :-0.8657285392897394
#
#
# At random state51, The training accuracy is :-0.9638066652604074
# At random state51, The test accuracy is :-0.5791339363656571
#
#
# At random state52, The training accuracy is :-0.9661571876864267
# At random state52, The test accuracy is :-0.40014603463255694
#
#
# At random state53, The training accuracy is :-0.962237147865974
# At random state53, The test accuracy is :-0.037452971766417154
#
#
# At random state54, The training accuracy is :-0.9438542261598561
# At random state54, The test accuracy is :-0.4691538858350529
#
#
# At random state55, The training accuracy is :-0.9499150299169432
# At random state55, The test accuracy is :-0.5470254153576577
#
#
# At random state56, The training accuracy is :-0.959429998623857
# At random state56, The test accuracy is :-0.5022121597223397
#
#
# At random state57, The training accuracy is :-0.9555536423501765
# At random state57, The test accuracy is :-0.6375208734524886
#
#
# At random state58, The training accuracy is :-0.9560631334451474
# At random state58, The test accuracy is :-0.7006170395668755
#
#
# At random state59, The training accuracy is :-0.9577416689035331
# At random state59, The test accuracy is :-0.41028074014372484
#
#
# At random state60, The training accuracy is :-0.9770562220499566
# At random state60, The test accuracy is :-0.15302000094308466
#
#
# At random state61, The training accuracy is :-0.9720926015977269
# At random state61, The test accuracy is :-0.30223066096141515
#
#
# At random state62, The training accuracy is :-0.9674836717742695
# At random state62, The test accuracy is :-0.43419919157742914
#
#
# At random state63, The training accuracy is :-0.9763508119515164
# At random state63, The test accuracy is :-0.4902430362574115
#
#
# At random state64, The training accuracy is :-0.9334019526836594
# At random state64, The test accuracy is :-0.7088464206197702
#
#
# At random state65, The training accuracy is :-0.9520783790634755
# At random state65, The test accuracy is :-0.39732684560553244
#
#
# At random state66, The training accuracy is :-0.9436255170350445
# At random state66, The test accuracy is :-0.45115816416787213
#
#
# At random state67, The training accuracy is :-0.9290404151659858
# At random state67, The test accuracy is :-0.8997471336491221
#
#
# At random state68, The training accuracy is :-0.9356172498450849
# At random state68, The test accuracy is :-0.7721825032075291
#
#
# At random state69, The training accuracy is :-0.9447839816141433
# At random state69, The test accuracy is :-0.24678277821913663
#
#
# At random state70, The training accuracy is :-0.9352206382877146
# At random state70, The test accuracy is :-0.3663762770690626
#
#
# At random state71, The training accuracy is :-0.9830280782532361
# At random state71, The test accuracy is :--2.42842328218644
#
#
# At random state72, The training accuracy is :-0.9320541943111897
# At random state72, The test accuracy is :-0.5674236584988619
#
#
# At random state73, The training accuracy is :-0.9316202794704544
# At random state73, The test accuracy is :-0.7955817644042085
#
#
# At random state74, The training accuracy is :-0.9602036885149636
# At random state74, The test accuracy is :--0.5995378999747312
#
#
# At random state75, The training accuracy is :-0.9074060504294138
# At random state75, The test accuracy is :-0.9389416196800837
#
#
# At random state76, The training accuracy is :-0.946924771278483
# At random state76, The test accuracy is :-0.4684647259490249
#
#
# At random state77, The training accuracy is :-0.9499849781035935
# At random state77, The test accuracy is :-0.373895036277891
#
#
# At random state78, The training accuracy is :-0.9365855374046388
# At random state78, The test accuracy is :-0.6711273437048244
#
#
# At random state79, The training accuracy is :-0.9501765143042682
# At random state79, The test accuracy is :-0.7272277814050219
#
#
# At random state80, The training accuracy is :-0.9396002137353626
# At random state80, The test accuracy is :-0.6334414374435777
#
#
# At random state81, The training accuracy is :-0.9547771725527431
# At random state81, The test accuracy is :-0.7221166725876018
#
#
# At random state82, The training accuracy is :-0.9363766379684952
# At random state82, The test accuracy is :-0.7428997639869075
#
#
# At random state83, The training accuracy is :-0.9535677914498931
# At random state83, The test accuracy is :-0.35992088809212364
#
#
# At random state84, The training accuracy is :-0.9374798380498826
# At random state84, The test accuracy is :-0.5992423961533975
#
#
# At random state85, The training accuracy is :-0.9186930988628256
# At random state85, The test accuracy is :-0.8413831310088531
#
#
# At random state86, The training accuracy is :-0.9509864865792859
# At random state86, The test accuracy is :--0.2573690537820703
#
#
# At random state87, The training accuracy is :-0.9229928050054078
# At random state87, The test accuracy is :-0.7246401657377667
#
#
# At random state88, The training accuracy is :-0.9609509308694176
# At random state88, The test accuracy is :--1.4871635884179204
#
#
# At random state89, The training accuracy is :-0.9369238017627887
# At random state89, The test accuracy is :-0.6505420404550867
#
#
# At random state90, The training accuracy is :-0.936527603573992
# At random state90, The test accuracy is :-0.7363796943689316
#
#
# At random state91, The training accuracy is :-0.9783665694818835
# At random state91, The test accuracy is :-0.35416546948874994
#
#
# At random state92, The training accuracy is :-0.969493883842668
# At random state92, The test accuracy is :-0.3630115293135334
#
#
# At random state93, The training accuracy is :-0.9491632372299249
# At random state93, The test accuracy is :--0.9021151017518594
#
#
# At random state94, The training accuracy is :-0.9692300563227106
# At random state94, The test accuracy is :-0.4031440952005815
#
#
# At random state95, The training accuracy is :-0.9146770061253713
# At random state95, The test accuracy is :-0.7707646069544829
#
#
# At random state96, The training accuracy is :-0.9582693328409194
# At random state96, The test accuracy is :-0.5001848352897676
#
#
# At random state97, The training accuracy is :-0.9251519860457412
# At random state97, The test accuracy is :-0.8359668559686606
#
#
# At random state98, The training accuracy is :-0.9560931386207492
# At random state98, The test accuracy is :-0.26560932846370133
#
#
# At random state99, The training accuracy is :-0.9227221218384355
# At random state99, The test accuracy is :-0.9046583186121654

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=99)

# %%
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
parameter = {'alpha':[0.001,0.01,0.1,1,10]}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10]})

# %%
GVC.best_params_
# Out:
# {'alpha': 1}

# %%
GVC.best_score_
# Out:
# 0.6066987653676461

# %%
GVC=GridSearchCV(Ridge(),parameter,cv=5)

# %%
GVC.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10]})

# %%
GVC.best_score_
# Out:
# 0.4291664549506023

# %%
GVC.best_params_
# Out:
# {'alpha': 10}

# %%
GVC=GridSearchCV(ElasticNet(),parameter,cv=5)

# %%
GVC.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10]})

# %%
GVC.best_score_
# Out:
# 0.5728695769222653

# %%
GVC.best_params_
# Out:
# {'alpha': 1}

# %%
final=Lasso(alpha=1)
final.fit(X_train,y_train)
# Out:
# Lasso(alpha=1)

# %%
pred=final.predict(X_test)

# %%
r2_score(y_test,pred)
# Out:
# 0.8618872755668385

# %%
mean_squared_error(y_test,pred)
# Out:
# 21.069863405192297

# %%
mean_absolute_error(y_test,pred)
# Out:
# 3.7701046348244702

# %%
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 4.590192088049507

# %%
import joblib
joblib.dump(final,'Baseball.obj')
# Out:
# ['Baseball.obj']

# %%
test=joblib.load('Baseball.obj')

# %%
test.predict(X_train)
# Out:
# array([85.50615791, 91.84638698, 80.42119978, 88.46487187, 73.3531548 ,
#        96.72038172, 81.78431485, 81.42447001, 70.89382924, 91.3479545 ,
#        88.3470976 , 74.51993249, 75.06871335, 70.35803879, 86.55663026,
#        69.81597126, 70.13104009, 81.46632199, 82.3455546 , 78.64031848,
#        84.12191967, 73.46929875, 81.39644099])
