# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('weather_aus.csv')

# %%
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
df.shape
# Out:
# (8425, 23)

# %%
df.dropna(axis=0)
# Out:
#             Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 907   2009-03-10  CoffsHarbour     19.8     27.1      24.4          8.6
# 908   2009-03-11  CoffsHarbour     18.7     25.6       6.8          3.8
# 909   2009-03-12  CoffsHarbour     16.5     25.5      16.8          2.8
# 910   2009-03-13  CoffsHarbour     18.5     26.9       0.0          3.2
# 911   2009-03-14  CoffsHarbour     18.2     28.2       0.0          6.8
# ...          ...           ...      ...      ...       ...          ...
# 8381  2012-11-06        Darwin     25.2     34.5       3.0          4.0
# 8382  2012-11-07        Darwin     26.2     33.3       0.0          6.0
# 8383  2012-11-08        Darwin     24.9     32.8      20.4          6.2
# 8384  2012-11-09        Darwin     25.5     33.1       0.0          4.8
# 8385  2012-11-10        Darwin     24.9     34.3       0.0          5.6
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
import datetime as dt
df.Date=pd.to_datetime(df.Date)
df.Date=df.Date.map(dt.datetime.toordinal)

# %%
df
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     733377   Albury     13.4     22.9       0.6          NaN       NaN
# 1     733378   Albury      7.4     25.1       0.0          NaN       NaN
# 2     733379   Albury     12.9     25.7       0.0          NaN       NaN
# 3     733380   Albury      9.2     28.0       0.0          NaN       NaN
# 4     733381   Albury     17.5     32.3       1.0          NaN       NaN
# ...      ...      ...      ...      ...       ...          ...       ...
# 8420  736501    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  736502    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  736503    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  736504    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  736505    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# ...

# %%
df.describe()
# Out:
#                 Date      MinTemp      MaxTemp     Rainfall  Evaporation  \
# count    8425.000000  8350.000000  8365.000000  8185.000000  4913.000000
# mean   734720.429674    13.193305    23.859976     2.805913     5.389395
# std       899.933399     5.403596     6.136408    10.459379     5.044484
# min    733377.000000    -2.000000     8.200000     0.000000     0.000000
# 25%    733966.000000     9.200000    19.300000     0.000000     2.600000
# 50%    734495.000000    13.300000    23.300000     0.000000     4.600000
# 75%    735487.000000    17.400000    28.000000     1.000000     7.000000
# max    736505.000000    28.500000    45.500000   371.000000   145.000000
#
#           Sunshine  WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# count  4431.000000    7434.000000   8349.000000   8318.000000  8366.000000
# mean      7.632205      40.174469     13.847646     18.533662    67.822496
# std       3.896235      14.665721     10.174579      9.766986    16.833283
# ...

# %%
df.skew()
# Out:
# Date              0.393962
# MinTemp          -0.089588
# MaxTemp           0.379297
# Rainfall         13.028837
# Evaporation      10.710605
# Sunshine         -0.519717
# WindGustSpeed     0.711103
# WindSpeed9am      0.956250
# WindSpeed3pm      0.491069
# Humidity9am      -0.255843
# Humidity3pm       0.117563
# Pressure9am      -0.022133
# Pressure3pm      -0.009385
# Cloud9am         -0.309417
# Cloud3pm         -0.232598
# Temp9am          -0.014699
# Temp3pm           0.395061
# dtype: float64

# %%
for i in df.columns:
    if df[i].dtypes=='float64':
        df[i]=df[i].fillna(df[i].mean())
    else:
        df[i]=df[i].fillna(df[i].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   int64
#  1   Location       8425 non-null   object
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    8425 non-null   object
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     8425 non-null   object
#  10  WindDir3pm     8425 non-null   object
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
df
# Out:
#         Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     733377   Albury     13.4  22.900000       0.6     5.389395  7.632205
# 1     733378   Albury      7.4  25.100000       0.0     5.389395  7.632205
# 2     733379   Albury     12.9  25.700000       0.0     5.389395  7.632205
# 3     733380   Albury      9.2  28.000000       0.0     5.389395  7.632205
# 4     733381   Albury     17.5  32.300000       1.0     5.389395  7.632205
# ...      ...      ...      ...        ...       ...          ...       ...
# 8420  736501    Uluru      2.8  23.400000       0.0     5.389395  7.632205
# 8421  736502    Uluru      3.6  25.300000       0.0     5.389395  7.632205
# 8422  736503    Uluru      5.4  26.900000       0.0     5.389395  7.632205
# 8423  736504    Uluru      7.8  27.000000       0.0     5.389395  7.632205
# 8424  736505    Uluru     14.9  23.859976       0.0     5.389395  7.632205
#
# ...

# %%
df.corr()
# Out:
#                    Date   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# Date           1.000000  0.016072  0.101686  0.004908     0.154082  0.065029
# MinTemp        0.016072  1.000000  0.717522  0.087684     0.254965  0.056184
# MaxTemp        0.101686  0.717522  1.000000 -0.087451     0.322405  0.378403
# Rainfall       0.004908  0.087684 -0.087451  1.000000     0.023517 -0.169432
# Evaporation    0.154082  0.254965  0.322405  0.023517     1.000000  0.226001
# Sunshine       0.065029  0.056184  0.378403 -0.169432     0.226001  1.000000
# WindGustSpeed -0.036425  0.230058  0.139998  0.086000     0.136371 -0.013778
# WindSpeed9am  -0.084309  0.136872  0.013314  0.050631     0.104294 -0.018069
# WindSpeed3pm  -0.045865  0.178349  0.088172  0.024791     0.101126  0.030145
# Humidity9am    0.086538 -0.130731 -0.390976  0.228800    -0.213108 -0.360831
# Humidity3pm   -0.037614  0.079048 -0.421879  0.235444    -0.161661 -0.440268
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   int64
#  1   Location       8425 non-null   object
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    8425 non-null   object
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     8425 non-null   object
#  10  WindDir3pm     8425 non-null   object
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=LabelEncoder().fit_transform(df[i])

# %%
df
# Out:
#         Date  Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     733377         1     13.4  22.900000       0.6     5.389395  7.632205
# 1     733378         1      7.4  25.100000       0.0     5.389395  7.632205
# 2     733379         1     12.9  25.700000       0.0     5.389395  7.632205
# 3     733380         1      9.2  28.000000       0.0     5.389395  7.632205
# 4     733381         1     17.5  32.300000       1.0     5.389395  7.632205
# ...      ...       ...      ...        ...       ...          ...       ...
# 8420  736501         9      2.8  23.400000       0.0     5.389395  7.632205
# 8421  736502         9      3.6  25.300000       0.0     5.389395  7.632205
# 8422  736503         9      5.4  26.900000       0.0     5.389395  7.632205
# 8423  736504         9      7.8  27.000000       0.0     5.389395  7.632205
# 8424  736505         9     14.9  23.859976       0.0     5.389395  7.632205
#
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   int64
#  1   Location       8425 non-null   int32
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    8425 non-null   int32
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     8425 non-null   int32
#  10  WindDir3pm     8425 non-null   int32
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
plt.figure(figsize=(20,40))
for i in enumerate(df):
    plt.xlabel(i)
    plt.subplot(8,3,i[0]+1)
    sns.boxplot(df[i[1]])

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
print(np.where(z>3))
# Out:
# (array([  12,   12,   44,   44,   52,   52,   60,   60,   61,   61,   62,
#          62,   62,   67,   68,   68,  123,  267,  296,  381,  381,  405,
#         406,  407,  407,  431,  462,  563,  568,  568,  569,  602,  683,
#         683,  699,  713,  748,  748,  770,  796,  797,  802,  928,  935,
#         949,  979,  980,  980,  980, 1008, 1009, 1011, 1138, 1148, 1149,
#        1151, 1189, 1202, 1203, 1237, 1241, 1264, 1265, 1357, 1411, 1412,
#        1413, 1479, 1480, 1481, 1513, 1535, 1587, 1644, 1661, 1665, 1673,
#        1680, 1774, 1819, 1873, 1898, 1903, 1945, 2016, 2028, 2043, 2063,
#        2074, 2108, 2116, 2186, 2201, 2219, 2219, 2230, 2231, 2265, 2429,
#        2488, 2500, 2505, 2527, 2527, 2541, 2593, 2676, 2677, 2735, 2827,
#        2835, 2849, 2849, 2855, 2859, 2863, 2869, 2877, 2883, 2890, 2891,
#        2897, 2898, 2900, 2901, 2905, 2909, 2911, 2919, 2925, 2933, 2939,
#        2947, 2953, 2961, 2967, 2975, 2989, 3003, 3051, 3051, 3058, 3059,
# ...

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#         Date  Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     733377         1     13.4  22.900000       0.6     5.389395  7.632205
# 1     733378         1      7.4  25.100000       0.0     5.389395  7.632205
# 2     733379         1     12.9  25.700000       0.0     5.389395  7.632205
# 3     733380         1      9.2  28.000000       0.0     5.389395  7.632205
# 4     733381         1     17.5  32.300000       1.0     5.389395  7.632205
# ...      ...       ...      ...        ...       ...          ...       ...
# 8420  736501         9      2.8  23.400000       0.0     5.389395  7.632205
# 8421  736502         9      3.6  25.300000       0.0     5.389395  7.632205
# 8422  736503         9      5.4  26.900000       0.0     5.389395  7.632205
# 8423  736504         9      7.8  27.000000       0.0     5.389395  7.632205
# 8424  736505         9     14.9  23.859976       0.0     5.389395  7.632205
#
# ...

# %%
df=df_new

# %%
df
# Out:
#         Date  Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     733377         1     13.4  22.900000       0.6     5.389395  7.632205
# 1     733378         1      7.4  25.100000       0.0     5.389395  7.632205
# 2     733379         1     12.9  25.700000       0.0     5.389395  7.632205
# 3     733380         1      9.2  28.000000       0.0     5.389395  7.632205
# 4     733381         1     17.5  32.300000       1.0     5.389395  7.632205
# ...      ...       ...      ...        ...       ...          ...       ...
# 8420  736501         9      2.8  23.400000       0.0     5.389395  7.632205
# 8421  736502         9      3.6  25.300000       0.0     5.389395  7.632205
# 8422  736503         9      5.4  26.900000       0.0     5.389395  7.632205
# 8423  736504         9      7.8  27.000000       0.0     5.389395  7.632205
# 8424  736505         9     14.9  23.859976       0.0     5.389395  7.632205
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x=StandardScaler().fit_transform(x)

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.493824 -1.508427  0.056444 -0.145732 -0.282088  0.110484 -0.013374
# 1    -1.492705 -1.508427 -1.058476  0.220676 -0.408537  0.110484 -0.013374
# 2    -1.491585 -1.508427 -0.036466  0.320605 -0.408537  0.110484 -0.013374
# 3    -1.490466 -1.508427 -0.724000  0.703668 -0.408537  0.110484 -0.013374
# 4    -1.489346 -1.508427  0.818306  1.419829 -0.197789  0.110484 -0.013374
# ...        ...       ...       ...       ...       ...       ...       ...
# 7982  2.003756  1.029423 -1.913248 -0.062457 -0.408537  0.110484 -0.013374
# 7983  2.004875  1.029423 -1.764592  0.253986 -0.408537  0.110484 -0.013374
# 7984  2.005995  1.029423 -1.430116  0.520464 -0.408537  0.110484 -0.013374
# 7985  2.007114  1.029423 -0.984148  0.537119 -0.408537  0.110484 -0.013374
# 7986  2.008234  1.029423  0.335174  0.014151 -0.408537  0.110484 -0.013374
#
# ...

# %%
df
# Out:
#         Date  Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     733377         1     13.4  22.900000       0.6     5.389395  7.632205
# 1     733378         1      7.4  25.100000       0.0     5.389395  7.632205
# 2     733379         1     12.9  25.700000       0.0     5.389395  7.632205
# 3     733380         1      9.2  28.000000       0.0     5.389395  7.632205
# 4     733381         1     17.5  32.300000       1.0     5.389395  7.632205
# ...      ...       ...      ...        ...       ...          ...       ...
# 8420  736501         9      2.8  23.400000       0.0     5.389395  7.632205
# 8421  736502         9      3.6  25.300000       0.0     5.389395  7.632205
# 8422  736503         9      5.4  26.900000       0.0     5.389395  7.632205
# 8423  736504         9      7.8  27.000000       0.0     5.389395  7.632205
# 8424  736505         9     14.9  23.859976       0.0     5.389395  7.632205
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
maxaccu=0
maxrs=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.30)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    score=accuracy_score(y_test,pred)
    
    if maxaccu>score:
        score=maxaccu
        maxrs=i
print('best accuracy score is :-',score,'at random state:-',i)
# Out:
# best accuracy score is :- 0.8389653733833959 at random state:- 199

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=199)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

# %%
model=[DecisionTreeClassifier(),SVC(),KNeighborsClassifier(),RandomForestClassifier(),GradientBoostingClassifier()]

# %%
for m in model:
    print('model name:-',m)
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    score=accuracy_score(pred,y_test)
    print(score)
    cv_score=cross_val_score(m,x,y,cv=5)
    print(cv_score)
    print('cross validation score is:-',cv_score.mean())
# Out:
# model name:- DecisionTreeClassifier()
# 0.8347934918648311
# [0.65206508 0.80475594 0.81840952 0.73137132 0.77332498]
# cross validation score is:- 0.7559853699403527
# model name:- SVC()
# 0.8569044639132248
# [0.85043805 0.81414268 0.81903569 0.81778334 0.84220413]
# cross validation score is:- 0.8287207788696422
# model name:- KNeighborsClassifier()
# 0.8427200667501042
# [0.81414268 0.81038798 0.82341891 0.79085786 0.81026925]
# cross validation score is:- 0.8098153374247554
# model name:- RandomForestClassifier()
# 0.8927826449728827
# [0.84793492 0.85294118 0.87977458 0.82028804 0.84721353]
# cross validation score is:- 0.8496304475773175
# model name:- GradientBoostingClassifier()
# 0.8531497705465165
# [0.84355444 0.80663329 0.77958673 0.67251096 0.84283031]
# cross validation score is:- 0.78902314492991

# %%
param={'random_state':[199],
      'criterion':['gini','entropy','log_loss']}

# %%
gd_rfc=GridSearchCV(RandomForestClassifier(),param_grid=param,cv=10)

# %%
gd_rfc.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'random_state': [199]})

# %%
gd_rfc.best_estimator_
# Out:
# RandomForestClassifier(random_state=199)

# %%
gd_rfc.best_params_
# Out:
# {'criterion': 'gini', 'random_state': 199}

# %%
gd_rfc.best_score_
# Out:
# 0.8813953488372093

# %%
RFC=RandomForestClassifier(criterion='gini',random_state=199)

# %%
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=199)

# %%
RFC_pred=RFC.predict(x_test)

# %%
print(accuracy_score(RFC_pred,y_test))
# Out:
# 0.8931998331247393

# %%
import joblib
joblib.dump(RFC,'Rainfall_weather_forecasting_project.obj')
# Out:
# ['Rainfall_weather_forecasting_project.obj']

# %%
test=joblib.load('Rainfall_weather_forecasting_project.obj')

# %%
test.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# 6201    1
# 6137    0
# 4176    0
# 1295    0
# 7273    0
#        ..
# 8346    0
# 542     0
# 6426    1
# 1079    0
# 4482    0
# Name: RainTomorrow, Length: 2397, dtype: int32
