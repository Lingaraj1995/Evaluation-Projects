# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('zomato1.csv')

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df2=pd.read_excel('Country-Code.xlsx')

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df=pd.merge(df1,df2)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.iloc[:,10]
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9551, dtype: int64

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        print(df[i].value_counts())
        
        print('='*120)
# Out:
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# ...
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64
# ...
# Sector 41, Noida                                                                         11
# Dilli Haat, INA, New Delhi                                                               11
# Greater Kailash (GK) 1, New Delhi                                                        10
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
plt.figure(figsize=(25,20))
plotnumber=1

for i in df.columns:
    if df[i].dtypes !='object':
        if plotnumber<=30:
            plt.xlabel(i)
            plt.subplot(5,5,plotnumber)
            sns.boxplot(df[i])
        plotnumber+=1

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
from sklearn.preprocessing import StandardScaler

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        print(df[i].value_counts())
    print('='*100)
# Out:
# ...
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# ...
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64
# ...
# Sector 41, Noida                                                                         11
# Dilli Haat, INA, New Delhi                                                               11
# Greater Kailash (GK) 1, New Delhi                                                        10
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
df
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
columns=df.columns

# %%
x
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.310940  0.044706  2.531111 -0.228533  1.614667 -1.542277 -1.523332
# 1    -0.312458 -0.224101  2.531111 -0.228533  0.589558 -0.206201 -0.230036
# 2    -0.312946 -0.352904  2.531111 -0.142317  0.055177 -1.108527 -1.095248
# 3    -0.310841  0.491783  2.531111 -0.142317  1.616615  0.645468  0.595986
# 4    -0.311319  0.872592  2.531111 -0.142317  1.616226  0.645468  0.595986
# ...        ...       ...       ...       ...       ...       ...       ...
# 9546 -0.356658  0.368580  3.341718  2.659685  0.539277 -0.446821 -0.465180
# 9547 -0.357452 -1.093055  3.341718  2.659685  0.553309 -0.336009 -0.359667
# 9548 -0.356649 -0.272635  3.341718  2.659685  0.554868 -0.329677 -0.350623
# 9549 -0.356614 -1.465464  3.341718  2.659685  0.555258 -0.329677 -0.350623
# 9550 -0.355330  1.673878  3.341718  2.659685 -0.110867  0.037585  0.011139
#
# ...

# %%
df
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
df
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
df=StandardScaler().fit_transform(df)

# %%
df=pd.DataFrame(df,columns=columns)

# %%
x=df.drop(columns='Average Cost for two')

# %%
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
y=df.iloc[:,10]

# %%
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
y
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9551, dtype: int64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
for i in range(50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    print('rs',i)
    print('MSE',mean_squared_error(y_test,pred))
    print('MAE',mean_absolute_error(y_test,pred))
    print('====================================================')
# Out:
# rs 0
# MSE 375510250.0995046
# MAE 1960.644548664815
# ...
# rs 1
# MSE 337523112.8432889
# MAE 1947.5622689837267
# ...
# rs 2
# MSE 64675475.54402753
# MAE 1961.793387614256
# ...
# rs 3
# MSE 69071099.83478032
# MAE 1808.879179630705
# ...
# rs 4
# MSE 79366777.77274835
# MAE 2100.374716474306
# ...
# rs 5
# MSE 337453976.3296743
# MAE 2123.5486930499637
# ...
# rs 6
# MSE 433979133.65075034
# MAE 2217.0207176308245
# ...
# rs 7
# MSE 144823845.51238722
# MAE 2040.3887600439168
# ...
# rs 8
# MSE 182441299.9268997
# MAE 2033.1431553606556
# ...
# rs 9
# MSE 141976728.9512705
# MAE 2016.5753445293233
# ...
# rs 10
# MSE 54177198.044370934
# MAE 1674.9524499864683
# ...
# rs 11
# MSE 436441568.5808292
# MAE 1970.4089962136402
# ...
# rs 12
# MSE 353613386.95121014
# MAE 1967.2348067044093
# ...
# rs 13
# MSE 397049312.062141
# MAE 2098.753477071877
# ...
# rs 14
# MSE 66037644.121976875
# MAE 1985.514104890063
# ...
# rs 15
# MSE 219312239.01745495
# MAE 2173.3195994803177
# ...
# rs 16
# MSE 18483140.83232369
# MAE 1726.2483141681864
# ...
# rs 17
# MSE 304564563.21752834
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=25)

# %%
x_train
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 6518       18461352             5431             1    88     6353       819
# 9187        2700241             4644             1   108     1805       570
# 1430           4618             6113             1    50     4488       258
# 4690         302142             1928             1    88     6383       540
# 6564           8671             2993             1    88     7525       834
# ...             ...              ...           ...   ...      ...       ...
# 1175       18445248             1534             1    50     4174        62
# 8447            396             4077             1    89     6907       907
# 2934           3504             5556             1    88     1507       189
# 6618           7428             2143             1    88     1481       834
# 8510       18244520             3059             1    89     8016       916
#
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor

# %%
model=[DecisionTreeRegressor(),Ridge(),SVR(),GradientBoostingRegressor()]

# %%
for m in model:
    print('model name',m)
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('MSE',mean_squared_error(y_test,pred))
    print('MAE',mean_absolute_error(y_test,pred))
    print('===================================================')
# Out:
# model name DecisionTreeRegressor()
# MSE 347935413.6113225
# MAE 757.5875356803044
# ...
# model name Ridge()
# MSE 77018788.99649864
# MAE 1949.0326267592277
# ...
# model name SVR()
# MSE 76100021.96157059
# MAE 706.0291387100111
# ...
# model name GradientBoostingRegressor()
# MSE 141000832.5212705
# MAE 641.5803261992703
# ...

# %%
param={'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],
      'criterion':['friedman_mse', 'squared_error']}

# %%
gbr_gd=GridSearchCV(GradientBoostingRegressor(),param_grid=param,cv=10)

# %%
gbr_gd.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile']})

# %%
gbr_gd.best_score_
# Out:
# 0.49768188484768683

# %%
gbr_gd.best_params_
# Out:
# {'criterion': 'squared_error', 'loss': 'huber'}

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   int32
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   int32
#  4   Address               9551 non-null   int32
#  5   Locality              9551 non-null   int32
#  6   Locality Verbose      9551 non-null   int32
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   int32
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   int32
#  12  Has Table booking     9551 non-null   int32
#  13  Has Online delivery   9551 non-null   int32
#  14  Is delivering now     9551 non-null   int32
# ...

# %%
df['Price range'].convert_dtypes(convert_string=True)
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: Int64

# %%
df['Price range']
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
y1=df['Price range']

# %%
y
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
x1=df.drop(columns='Price range')

# %%
x1
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
x1=StandardScaler().fit_transform(x1)

# %%
x1=pd.DataFrame(x1)

# %%
x1
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.310940  0.044706  2.531111 -0.228533  1.614667 -1.542277 -1.523332
# 1    -0.312458 -0.224101  2.531111 -0.228533  0.589558 -0.206201 -0.230036
# 2    -0.312946 -0.352904  2.531111 -0.142317  0.055177 -1.108527 -1.095248
# 3    -0.310841  0.491783  2.531111 -0.142317  1.616615  0.645468  0.595986
# 4    -0.311319  0.872592  2.531111 -0.142317  1.616226  0.645468  0.595986
# ...        ...       ...       ...       ...       ...       ...       ...
# 9546 -0.356658  0.368580  3.341718  2.659685  0.539277 -0.446821 -0.465180
# 9547 -0.357452 -1.093055  3.341718  2.659685  0.553309 -0.336009 -0.359667
# 9548 -0.356649 -0.272635  3.341718  2.659685  0.554868 -0.329677 -0.350623
# 9549 -0.356614 -1.465464  3.341718  2.659685  0.555258 -0.329677 -0.350623
# 9550 -0.355330  1.673878  3.341718  2.659685 -0.110867  0.037585  0.011139
#
# ...

# %%
for i in range(50):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=.22,random_state=i)
    lr=LinearRegression()
    lr.fit(x1_train,y1_train)
    pred=lr.predict(x1_test)
    print('rs',i)
    print('MSE',mean_squared_error(y1_test,pred))
    print('MAE',mean_absolute_error(y1_test,pred))
    print('====================================================')
# Out:
# rs 0
# MSE 0.4135484681506693
# MAE 0.5158873850530654
# ...
# rs 1
# MSE 0.4224989153445214
# MAE 0.5241647106577083
# ...
# rs 2
# MSE 0.4222180494439771
# MAE 0.5288941519288981
# ...
# rs 3
# MSE 0.4352919728488877
# MAE 0.5307091973976311
# ...
# rs 4
# MSE 0.4027382698218883
# MAE 0.5202171037759816
# ...
# rs 5
# MSE 0.45535599419731954
# MAE 0.5375141481976525
# ...
# rs 6
# MSE 0.41293057041992587
# MAE 0.5179131756569975
# ...
# rs 7
# MSE 0.41810072349456084
# MAE 0.5171025958462953
# ...
# rs 8
# MSE 0.4126068686489423
# MAE 0.524009227065743
# ...
# rs 9
# MSE 0.4351247495172206
# MAE 0.5300819548502963
# ...
# rs 10
# MSE 0.41020900538197824
# MAE 0.5196433620172145
# ...
# rs 11
# MSE 0.41094356840596297
# MAE 0.5171144258751753
# ...
# rs 12
# MSE 0.43899730747971916
# MAE 0.5290875264140661
# ...
# rs 13
# MSE 0.4289677728026843
# MAE 0.5215231802551208
# ...
# rs 14
# MSE 0.4195572237529481
# MAE 0.5244825292982055
# ...
# rs 15
# MSE 0.41327017585966497
# MAE 0.515978948935042
# ...
# rs 16
# MSE 0.3942198052276361
# MAE 0.5066119805753146
# ...
# rs 17
# ...

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=.22,random_state=30)

# %%
model=[DecisionTreeRegressor(),Ridge(),SVR(),GradientBoostingRegressor()]
for m in model:
    print('model name',m)
    m.fit(x1_train,y1_train)
    pred=m.predict(x1_test)
    print('MSE',mean_squared_error(y1_test,pred))
    print('MAE',mean_absolute_error(y1_test,pred))
    print('===================================================')
# Out:
# model name DecisionTreeRegressor()
# MSE 0.02093244529019981
# MAE 0.02093244529019981
# ...
# model name Ridge()
# MSE 0.4313146787438171
# MAE 0.5229386907348275
# ...
# model name SVR()
# MSE 0.35358155510452693
# MAE 0.41464566274840914
# ...
# model name GradientBoostingRegressor()
# MSE 0.019419926852696653
# MAE 0.05704962013450846
# ...

# %%
gbr_gd1=GridSearchCV(GradientBoostingRegressor(),param_grid=param,cv=10)

# %%
gbr_gd1.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile']})

# %%
gbr_gd1.best_score_
# Out:
# 0.9719961574238367

# %%
gbr_gd1.best_params_
# Out:
# {'criterion': 'squared_error', 'loss': 'squared_error'}

# %%
gbr1=GradientBoostingRegressor(criterion='squared_error',loss='squared_error')

# %%
gbr1.fit(x1_train,y1_train)
# Out:
# GradientBoostingRegressor(criterion='squared_error')

# %%
pred=gbr1.predict(x1_test)

# %%
print('mse',mean_squared_error(y1_test,pred))
# Out:
# mse 0.019134736381206507

# %%
print(r2_score(y1_test,pred))
# Out:
# 0.97744141537931

# %%
gbr1.score(x_train,y_train)
# Out:
# -0.00515780989704262

# %%
import joblib
joblib.dump(gbr1,'')
