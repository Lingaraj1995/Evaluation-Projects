# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('income_data.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.Income
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32555     <=50K
# 32556      >50K
# 32557     <=50K
# 32558     <=50K
# 32559      >50K
# Name: Income, Length: 32560, dtype: object

# %%
df.Income.value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
columns=['Age','Fnlwgt','Education_num','Capital_gain','Capital_loss','Hours_per_week']
plt.figure(figsize=(20,15))
for i in enumerate(columns):
    plt.subplot(3,2,i[0]+1)
    sns.boxplot(df[i[1]])

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        print('not reqd')
    else:
        print(i,' --',df[i].skew())
# Out:
# Age  -- 0.5587376395152729
# not reqd
# Fnlwgt  -- 1.4469722429475549
# not reqd
# Education_num  -- -0.31162989158397764
# not reqd
# not reqd
# not reqd
# not reqd
# not reqd
# Capital_gain  -- 11.953689856702193
# Capital_loss  -- 4.594548858598902
# Hours_per_week  -- 0.22763579151335658
# not reqd
# not reqd

# %%
from sklearn.preprocessing import power_transform

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        print('not reqd')
    else:
        print(i,' --',df[i].skew())
# Out:
# Age  -- 0.5587376395152729
# not reqd
# Fnlwgt  -- 1.4469722429475549
# not reqd
# Education_num  -- -0.31162989158397764
# not reqd
# not reqd
# not reqd
# not reqd
# not reqd
# Capital_gain  -- 11.953689856702193
# Capital_loss  -- 4.594548858598902
# Hours_per_week  -- 0.22763579151335658
# not reqd
# not reqd

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        print('not reqd')
    elif df[i].skew()>0.6:
            df[[i]]=power_transform(df[[i]])
    else:
        print('done')
# Out:
# done
# not reqd
# not reqd
# done
# not reqd
# not reqd
# not reqd
# not reqd
# not reqd
# done
# not reqd
# not reqd

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        print('not reqd')
    else:
        print(i,' --',df[i].skew())
# Out:
# Age  -- 0.5587376395152729
# not reqd
# Fnlwgt  -- 0.016914467666713666
# not reqd
# Education_num  -- -0.31162989158397764
# not reqd
# not reqd
# not reqd
# not reqd
# not reqd
# Capital_gain  -- 3.0169506030126136
# Capital_loss  -- 4.299510809990865
# Hours_per_week  -- 0.22763579151335658
# not reqd
# not reqd

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        print('not reqd')
    elif df[i].skew()>0.6:
            df[[i]]=power_transform(df[[i]])
    else:
        print('done')
# Out:
# done
# not reqd
# done
# not reqd
# done
# not reqd
# not reqd
# not reqd
# not reqd
# not reqd
# done
# not reqd
# not reqd

# %%
for i in df.columns:
    if df[i].dtypes == 'object':
        print('not reqd')
    else:
        print(i,' --',df[i].skew())
# Out:
# Age  -- 0.5587376395152729
# not reqd
# Fnlwgt  -- 0.016914467666713666
# not reqd
# Education_num  -- -0.31162989158397764
# not reqd
# not reqd
# not reqd
# not reqd
# not reqd
# Capital_gain  -- 3.016950568415086
# Capital_loss  -- 4.299510809990863
# Hours_per_week  -- 0.22763579151335658
# not reqd
# not reqd

# %%
df.skew()
# Out:
# Age               0.558738
# Fnlwgt            0.016914
# Education_num    -0.311630
# Capital_gain      3.016951
# Capital_loss      4.299511
# Hours_per_week    0.227636
# dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df_corr=df.corr()

# %%
df_corr
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.069881       0.036527      0.120112      0.050537
# Fnlwgt         -0.069881  1.000000      -0.041339     -0.002915     -0.006268
# Education_num   0.036527 -0.041339       1.000000      0.115351      0.076396
# Capital_gain    0.120112 -0.002915       0.115351      1.000000     -0.066667
# Capital_loss    0.050537 -0.006268       0.076396     -0.066667      1.000000
# Hours_per_week  0.068756 -0.022200       0.148127      0.075032      0.050439
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.022200
# Education_num         0.148127
# Capital_gain          0.075032
# Capital_loss          0.050439
# Hours_per_week        1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for i in df.columns:
    if df[i].dtypes== 'object':
        df[i]=LabelEncoder().fit_transform(df[i])

# %%
df
# Out:
#        Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6 -1.089889          9             13               2
# 1       38          4  0.398743         11              9               0
# 2       53          4  0.562540          1              7               2
# 3       28          4  1.340398          9             13               2
# 4       37          4  0.957182         12             14               2
# ...    ...        ...       ...        ...            ...             ...
# 32555   27          4  0.746749          7             12               2
# 32556   40          4 -0.193298         11              9               2
# 32557   58          4 -0.219755         11              9               6
# 32558   22          4  0.271668         11              9               4
# 32559   52          5  0.982165         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
df_corr=df.corr()

# %%
df_corr
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.069881  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016352   0.023537       0.052015
# Fnlwgt         -0.069881  -0.016352  1.000000  -0.029094      -0.041339
# Education      -0.010508   0.023537 -0.029094   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.041339   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.027809  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.002514  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.009995  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.014211   0.014135       0.031825
# Sex             0.088832   0.095942  0.023510  -0.027349       0.012256
# Capital_gain    0.120112   0.018226 -0.002915   0.021325       0.115351
# Capital_loss    0.050537   0.010133 -0.006268   0.016480       0.076396
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
print(np.where(z>3))
# Out:
# (array([    3,     7,     8, ..., 32550, 32552, 32559], dtype=int64), array([13, 10, 10, ...,  8,  8, 10], dtype=int64))

# %%
df.shape
# Out:
# (32560, 15)

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (25342, 15)

# %%
df=df_new

# %%
df
# Out:
#        Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6 -1.089889          9             13               2
# 1       38          4  0.398743         11              9               0
# 2       53          4  0.562540          1              7               2
# 4       37          4  0.957182         12             14               2
# 5       49          4 -0.131837          6              5               3
# ...    ...        ...       ...        ...            ...             ...
# 32554   22          4  1.144034         15             10               4
# 32555   27          4  0.746749          7             12               2
# 32556   40          4 -0.193298         11              9               2
# 32557   58          4 -0.219755         11              9               6
# 32558   22          4  0.271668         11              9               4
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
sns.scatterplot(x='Age',y='Income',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.scatterplot(x='Workclass',y='Income',data=df)
# Out:
# <Axes: xlabel='Workclass', ylabel='Income'>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=StandardScaler().fit_transform(x)

# %%
x
# Out:
# array([[ 9.27863137e-01,  1.47920791e+00, -1.11360029e+00, ...,
#          8.32667268e-17, -2.38934798e+00,  1.99371948e-01],
#        [ 2.75364306e-02,  9.63656915e-02,  4.05099567e-01, ...,
#          8.32667268e-17,  3.00016983e-02,  1.99371948e-01],
#        [ 1.15294481e+00,  9.63656915e-02,  5.72205569e-01, ...,
#          8.32667268e-17,  3.00016983e-02,  1.99371948e-01],
#        ...,
#        [ 1.77590882e-01,  9.63656915e-02, -1.98899181e-01, ...,
#          8.32667268e-17,  3.00016983e-02,  1.99371948e-01],
#        [ 1.52808094e+00,  9.63656915e-02, -2.25890525e-01, ...,
#          8.32667268e-17,  3.00016983e-02,  1.99371948e-01],
#        [-1.17289918e+00,  9.63656915e-02,  2.75458137e-01, ...,
#          8.32667268e-17, -1.76210918e+00,  1.99371948e-01]])

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.927863  1.479208 -1.113600 -0.335424  1.266466 -0.419137 -0.593988
# 1      0.027536  0.096366  0.405100  0.173623 -0.409480 -1.722183 -0.123152
# 2      1.152945  0.096366  0.572206 -2.371609 -1.247453 -0.419137 -0.123152
# 3     -0.047491  0.096366  0.974819  0.428146  1.685453 -0.419137 -0.593988
# 4      0.852836  0.096366 -0.136197 -1.098993 -2.085426  0.232386  0.347683
# ...         ...       ...       ...       ...       ...       ...       ...
# 25337 -1.172899  0.096366  1.165445  1.191715  0.009507  0.883909  1.053935
# 25338 -0.797763  0.096366  0.760135 -0.844470  0.847480 -0.419137  1.524770
# 25339  0.177591  0.096366 -0.198899  0.173623 -0.409480 -0.419137  0.112265
# 25340  1.528081  0.096366 -0.225891  0.173623 -0.409480  2.186955 -1.300240
# 25341 -1.172899  0.096366  0.275458  0.173623 -0.409480  0.883909 -1.300240
#
# ...

# %%
maxaccu=0
maxrs=0
for i in range(0,100):
    lg=LogisticRegression()
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=i)
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    score=accuracy_score(pred,y_test)
    
    if maxaccu>score:
        score=maxaccu
        maxrs=i
    
print('best accuracy score is:-',score,'at random state:-',i)
# Out:
# best accuracy score is:- 0.8342898134863702 at random state:- 99

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=99,test_size=.22)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.svm import SVC

# %%
model=[DecisionTreeClassifier(),RandomForestClassifier(),GradientBoostingClassifier(),SVC()]

# %%
for m in model:
    print('best accuracy for:-',m)
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('accuscore is:-',accuracy_score(y_test,pred))
    print('confusion matrix:-',confusion_matrix(y_test,pred))
    print('classification report:-',classification_report(y_test,pred))
    
    score=cross_val_score(m,x,y,cv=5)
    print(score)
    print('validation score is:-',score.mean())
    print('================================================================================')
# Out:
# best accuracy for:- DecisionTreeClassifier()
# accuscore is:- 0.8020086083213773
# confusion matrix:- [[3951  571]
#  [ 533  521]]
# classification report:-               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      4522
#            1       0.48      0.49      0.49      1054
#
#     accuracy                           0.80      5576
#    macro avg       0.68      0.68      0.68      5576
# weighted avg       0.80      0.80      0.80      5576
#
# [0.79779049 0.79719866 0.80445935 0.80564325 0.79972376]
# validation score is:- 0.8009631022434991
# ...
# best accuracy for:- RandomForestClassifier()
# accuscore is:- 0.8479196556671449
# confusion matrix:- [[4199  323]
#  [ 525  529]]
# classification report:-               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4522
#            1       0.62      0.50      0.56      1054
#
#     accuracy                           0.85      5576
# ...

# %%
param={'criterion':['friedman_mse', 'squared_error'],
      'random_state': [99]}

# %%
grid_gbc=GridSearchCV(GradientBoostingClassifier(),param,cv=10)
grid_gbc.fit(x,y)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingClassifier(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'random_state': [99]})

# %%
grid_gbc.best_estimator_
# Out:
# GradientBoostingClassifier(random_state=99)

# %%
grid_gbc.best_params_
# Out:
# {'criterion': 'friedman_mse', 'random_state': 99}

# %%
grid_gbc.best_score_
# Out:
# 0.8571545015403919

# %%
grid_gbc_pred=grid_gbc.best_estimator_.predict(x_test)

# %%
accuracy_score(grid_gbc_pred,y_test)
# Out:
# 0.8667503586800573

# %%
import joblib
joblib.dump(grid_gbc.best_estimator_,'census_income_predict.obj')
# Out:
# ['census_income_predict.obj']

# %%
test=joblib.load('census_income_predict.obj')

# %%
test.predict(x_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])
